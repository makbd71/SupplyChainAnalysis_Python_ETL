# %% [markdown]
# <a href="https://colab.research.google.com/github/makbd71/SupplyChainAnalysis_Python_ETL/blob/main/extract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Extract - install kaggle

# !pip install kagglehub

# %%
#Download Dataset from kaggle

import kagglehub

path = kagglehub.dataset_download("datasetengineer/logistics-and-supply-chain-dataset")

print("dataset path:", path)
# Out:
# ...
# 100%|██████████| 6.89M/6.89M [00:01<00:00, 5.95MB/s]
# Extracting files...
# dataset path: /root/.cache/kagglehub/datasets/datasetengineer/logistics-and-supply-chain-dataset/versions/1

# %%
import os

print(os.listdir(path))
# Out:
# ['dynamic_supply_chain_logistics_dataset.csv']
